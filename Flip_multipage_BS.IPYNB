# %% [markdown]
# ## Scraping  Multiple Page with BeautifulSoup

# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import time

# %%
names = []
prices = []
description = []

# %%
for i in range(1,21):
    url = "https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=" + str(i)
    print("Page"+str(i) , url)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    table = soup.find('div', class_="DOjaWF gdgoEp")

    name = table.find_all('div', class_="KzDlHZ")
    if name:
        for i in name:
            n = i.text
            names.append(n)
    else:
        names.append('-')
      

    price = table.find_all('div', class_="Nx9bqj _4b5DiR")
    if price:
        for i in price: 
            p = i.text
            prices.append(p)
    else:
        prices.append('-')
    
    desc = table.find_all('ul', class_="G4BRas")
    if desc:
        for i in desc:
            d = i.text
            description.append(d)
    else:
        description.append('-')
# Out:
# Page1 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1
# Page2 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2
# Page3 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3
# Page4 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4
# Page5 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5
# Page6 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6
# Page7 https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7
# ...

# %%
df = pd.DataFrame({'Product Name': names, 'Product Price': prices, 'Product Description': description})

# %%
df
# Out:
#                                           Product Name Product Price  \
# 0                 Apple iPhone 16 Plus (Black, 256 GB)       ₹94,900
# 1                      Apple iPhone 16 (Black, 256 GB)       ₹84,900
# 2                       Apple iPhone 13 (Blue, 128 GB)       ₹44,999
# 3                 Apple iPhone 16 Plus (Black, 512 GB)     ₹1,14,900
# 4           Apple iPhone 16 Plus (Ultramarine, 256 GB)       ₹94,900
# 5                 Apple iPhone 16 Plus (Black, 128 GB)       ₹84,900
# 6                      Apple iPhone 16 (White, 128 GB)       ₹74,900
# 7                Apple iPhone 16 (Ultramarine, 256 GB)       ₹84,900
# 8                      Apple iPhone 16 (White, 256 GB)       ₹84,900
# 9                      Apple iPhone 16 (Black, 128 GB)       ₹74,900
# 10               Apple iPhone 16 (Ultramarine, 128 GB)       ₹74,900
# 11          Apple iPhone 16 Plus (Ultramarine, 512 GB)     ₹1,14,900
# 12          Apple iPhone 16 Plus (Ultramarine, 128 GB)       ₹84,900
# ...
